# %% [markdown]
# <a href="https://colab.research.google.com/github/tu26010-7431-hue/Tu26010/blob/main/Chap04_Ex_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
# %matplotlib inline
# %precision 3
np.random.seed(0)

# %%
import requests,zipfile
from io import StringIO
import io

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00356/student.zip"
r = requests.get(url, stream=True)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()

# %%
# 練習問題4-6
student_data_math = pd.read_csv("student-mat.csv", sep=";")
plt.hist(student_data_math.G1)
plt.grid(True)

# %%
student_data_math.G1.plot(kind="kde",style="k--")
plt.grid(True)
