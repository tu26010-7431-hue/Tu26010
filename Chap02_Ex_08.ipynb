# %% [markdown]
# <a href="https://colab.research.google.com/github/tu26010-7431-hue/Tu26010/blob/main/Chap02_Ex_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas import Series,DataFrame
import pandas as pd

attri_data1 = {"ID":["1","2","3","4","5"],"Sex":["F","F","M","M","F"],"Money":[1000,2000,500,300,700],"Name":["Sato","Horie","Kondo","Kawada","Matsubara"]}
attri_data_frame1 = DataFrame(attri_data1)
attri_data2 = {"ID":["3","4","7"],"Math":[60,30,40],"English":[80,20,30]}
attri_data_frame2 = DataFrame(attri_data2)

merge_data = attri_data_frame1.merge(attri_data_frame2)
merge_data.mean(numeric_only=True)
# Out:
# Money      400.0
# Math        45.0
# English     50.0
# dtype: float64
