# %% [markdown]
# <a href="https://colab.research.google.com/github/tu26010-7431-hue/Tu26010/blob/main/Chap02_Ex_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy import linalg as linalg

a = np.array([[1,2,3],[1,3,2],[3,1,2]])
print(linalg.det(a))
# Out:
# -12.0
