# %% [markdown]
# <a href="https://colab.research.google.com/github/tu26010-7431-hue/Tu26010/blob/main/Chap04_Ex_07%E2%88%BC09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import numpy.random as random
# %matplotlib inline
# %precision 3
np.random.seed(0)

# %%
#練習問題4-7
for df,c in zip([5,25,50],"bgr"):
  x = random.chisquare(df,1000)
  plt.hist(x, 20,  color=c)

# %%
#　練習問題4-8
x = random.standard_t(100,1000)
plt.hist(x)
plt.grid(True)

# %%
#　練習問題4-9
for df, c in zip([(10,30),(20,25)],'bg'):
  x = random.f(df[0],df[1],1000)
  plt.hist(x, 100, color=c)
