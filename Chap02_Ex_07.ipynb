# %% [markdown]
# <a href="https://colab.research.google.com/github/tu26010-7431-hue/Tu26010/blob/main/Chap02_Ex_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas import Series,DataFrame
import pandas as pd

attri_data1 = {"ID":["1","2","3","4","5"],"Sex":["F","F","M","M","F"],"Money":[1000,2000,500,300,700],"Name":["Sato","Horie","Kondo","Kawada","Matsubara"]}
atri_data_frame1 = DataFrame(attri_data1)

atri_data_frame1[atri_data_frame1.Money>=500]
# Out:
#   ID Sex  Money       Name
# 0  1   F   1000       Sato
# 1  2   F   2000      Horie
# 2  3   M    500      Kondo
# 4  5   F    700  Matsubara
