# %% [markdown]
# <a href="https://colab.research.google.com/github/tu26010-7431-hue/Tu26010/blob/main/Chap02_Ex_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.optimize import newton

def my_function(x):
  return(x**3 + 2*x + 1)
print(newton(my_function,0))
print(my_function(newton(my_function,0)))
# Out:
# -0.45339765151640365
# 3.3306690738754696e-16
